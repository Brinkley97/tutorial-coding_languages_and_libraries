# %% [markdown]
# # Crime dataset from Pandas Cookbook
#
# - This data > CSV bc the latter only stores raw text
# - Set index function
#     - SYNTAX : dataset.set_index('COLUMN NAME')
#
# - Get multiple rows with single date
#     - SYNTAX : dataset.loc['DATE']

# %%
import numpy as np
import pandas as pd
import matplotlib as plot

# %%
file = "/Users/brinkley97/Documents/development/tutorial-python_libraries/pandas/datasets/crime.h5"

# %%
def load_data(file):
    original_data = pd.read_hdf(file)
    # original_data = pd.DataFrame(file)
    copy_of_data = original_data.copy()
    return copy_of_data

# %%
copy_of_data = load_data(file)
copy_of_data
# Out:
#                      OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID       REPORTED_DATE  \
# 0          traffic-accident-dui-duid    traffic-accident 2014-06-29 02:01:00
# 1         vehicular-eluding-no-chase    all-other-crimes 2014-06-29 01:54:00
# 2               disturbing-the-peace     public-disorder 2014-06-29 02:00:00
# 3                             curfew     public-disorder 2014-06-29 02:18:00
# 4                 aggravated-assault  aggravated-assault 2014-06-29 04:17:00
# ...                              ...                 ...                 ...
# 460906    burglary-business-by-force            burglary 2017-09-13 05:48:00
# 460907  weapon-unlawful-discharge-of    all-other-crimes 2017-09-12 20:37:00
# 460908        traf-habitual-offender    all-other-crimes 2017-09-12 16:32:00
# 460909       criminal-mischief-other     public-disorder 2017-09-12 13:04:00
# 460910                   theft-other             larceny 2017-09-12 09:30:00
#
# ...

# %%
type(copy_of_data.dtypes), copy_of_data.dtypes
# Out:
# (pandas.core.series.Series,
#  OFFENSE_TYPE_ID              category
#  OFFENSE_CATEGORY_ID          category
#  REPORTED_DATE          datetime64[ns]
#  GEO_LON                       float64
#  GEO_LAT                       float64
#  NEIGHBORHOOD_ID              category
#  IS_CRIME                        int64
#  IS_TRAFFIC                      int64
#  dtype: object)

# %%
type(copy_of_data.keys()), copy_of_data.keys()
# Out:
# (pandas.core.indexes.base.Index,
#  Index(['OFFENSE_TYPE_ID', 'OFFENSE_CATEGORY_ID', 'REPORTED_DATE', 'GEO_LON',
#         'GEO_LAT', 'NEIGHBORHOOD_ID', 'IS_CRIME', 'IS_TRAFFIC'],
#        dtype='object'))

# %%
copy_of_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 460911 entries, 0 to 460910
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   OFFENSE_TYPE_ID      460911 non-null  category
#  1   OFFENSE_CATEGORY_ID  460911 non-null  category
#  2   REPORTED_DATE        460911 non-null  datetime64[ns]
#  3   GEO_LON              457296 non-null  float64
#  4   GEO_LAT              457296 non-null  float64
#  5   NEIGHBORHOOD_ID      460911 non-null  category
#  6   IS_CRIME             460911 non-null  int64
#  7   IS_TRAFFIC           460911 non-null  int64
# dtypes: category(3), datetime64[ns](1), float64(2), int64(2)
# memory usage: 22.9 MB

# %%
reported_date_as_index = copy_of_data.set_index('REPORTED_DATE')
reported_date_as_index
# Out:
#                                   OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2014-06-29 02:01:00     traffic-accident-dui-duid    traffic-accident
# 2014-06-29 01:54:00    vehicular-eluding-no-chase    all-other-crimes
# 2014-06-29 02:00:00          disturbing-the-peace     public-disorder
# 2014-06-29 02:18:00                        curfew     public-disorder
# 2014-06-29 04:17:00            aggravated-assault  aggravated-assault
# ...                                           ...                 ...
# 2017-09-13 05:48:00    burglary-business-by-force            burglary
# 2017-09-12 20:37:00  weapon-unlawful-discharge-of    all-other-crimes
# 2017-09-12 16:32:00        traf-habitual-offender    all-other-crimes
# 2017-09-12 13:04:00       criminal-mischief-other     public-disorder
# 2017-09-12 09:30:00                   theft-other             larceny
#
#                         GEO_LON    GEO_LAT            NEIGHBORHOOD_ID  \
# REPORTED_DATE
# ...

# %%
reported_date_as_index.loc['2017-09-12']
# Out:
#                                   OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID  \
# REPORTED_DATE
# 2017-09-12 15:59:00              traffic-accident    traffic-accident
# 2017-09-12 01:33:00     criminal-mischief-mtr-veh     public-disorder
# 2017-09-12 00:37:00                   theft-other             larceny
# 2017-09-12 02:45:00        theft-of-motor-vehicle          auto-theft
# 2017-09-12 04:59:00        theft-of-motor-vehicle          auto-theft
# ...                                           ...                 ...
# 2017-09-12 14:00:00   forgery-poss-of-forged-inst  white-collar-crime
# 2017-09-12 20:37:00  weapon-unlawful-discharge-of    all-other-crimes
# 2017-09-12 16:32:00        traf-habitual-offender    all-other-crimes
# 2017-09-12 13:04:00       criminal-mischief-other     public-disorder
# 2017-09-12 09:30:00                   theft-other             larceny
#
#                         GEO_LON    GEO_LAT NEIGHBORHOOD_ID  IS_CRIME  \
# REPORTED_DATE
# ...

# %%
reported_date_as_index.groupby(year)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-a0bf890e49c8> in <module>
# ----> 1 reported_date_as_index.groupby(year)
#
# NameError: name 'year' is not defined
